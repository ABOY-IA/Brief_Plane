# %% [markdown]
# ### 1. Préparation du pipeline et des modèles
# Modèles utilisés :
# Logistic Regression
# Naive Bayes
# Random Forest
# Gradient Boosting

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, HistGradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import numpy as np

# Charger les données
data = pd.read_csv("Airline_Dataset.csv")

# Renommer les colonnes
data.rename(columns=lambda x: x.strip().replace(" ", "_").lower(), inplace=True)

# Gérer les valeurs manquantes
data["arrival_delay_in_minutes"] = data["arrival_delay_in_minutes"].fillna(
    data["arrival_delay_in_minutes"].median()
)

# Combiner les retards
data["total_delay"] = data["departure_delay_in_minutes"] + data["arrival_delay_in_minutes"]

# Étiqueter la satisfaction
data["satisfaction"] = data["satisfaction"].apply(lambda x: 1 if x == "satisfied" else 0)

# Supprimer les colonnes non représentatives
columns_to_drop = ["id", "departure_delay_in_minutes", "arrival_delay_in_minutes"]
data.drop(columns=columns_to_drop, inplace=True)

# Identifier les colonnes catégoriques et numériques
categorical_columns = data.select_dtypes(include=["object"]).columns
numerical_columns = data.select_dtypes(include=["number"]).drop(columns=["satisfaction"]).columns

# Configurer le prétraitement
categorical_preprocessor = OneHotEncoder(drop="first", sparse_output=False)
numerical_preprocessor = StandardScaler()

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numerical_preprocessor, numerical_columns),
        ("cat", categorical_preprocessor, categorical_columns),
    ]
)

# Diviser les données en caractéristiques (X) et cible (y)
X = data.drop(columns=["satisfaction"])
y = data["satisfaction"]

# Séparer les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# Définir les modèles
models = {
    "logistic_regression": Pipeline([
        ("preprocessor", preprocessor),
        ("classifier", LogisticRegression(max_iter=1000, random_state=42))
    ]),
    "naive_bayes": Pipeline([
        ("preprocessor", preprocessor),
        ("classifier", GaussianNB())
    ]),
    "random_forest": Pipeline([
        ("preprocessor", preprocessor),
        ("classifier", RandomForestClassifier(random_state=42))
    ]),
    "gradient_boosting": Pipeline([
        ("preprocessor", preprocessor),
        ("classifier", GradientBoostingClassifier(random_state=42))
    ]),
    "ada_boosting": Pipeline([
        ("preprocessor", preprocessor),
        ("classifier", AdaBoostClassifier(random_state=42))
    ]),
    "hist_gradient_boosting": Pipeline([
        ("preprocessor", preprocessor),
        ("classifier", HistGradientBoostingClassifier(random_state=42))
    ])
}

# Tester les modèles avant optimisation
initial_results = {}
for name, pipeline in models.items():
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    initial_results[name] = accuracy_score(y_test, y_pred)
    print(f"Model: {name}")
    print(classification_report(y_test, y_pred))
# Out:
# Model: logistic_regression
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     14690
#            1       0.87      0.84      0.85     11286
#
#     accuracy                           0.87     25976
#    macro avg       0.87      0.87      0.87     25976
# weighted avg       0.87      0.87      0.87     25976
#
# Model: naive_bayes
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88     14690
#            1       0.86      0.81      0.84     11286
#
#     accuracy                           0.86     25976
#    macro avg       0.86      0.86      0.86     25976
# weighted avg       0.86      0.86      0.86     25976
#
# Model: random_forest
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     14690
#            1       0.97      0.94      0.95     11286
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976
#
# Model: gradient_boosting
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     14690
#            1       0.94      0.92      0.93     11286
#
#     accuracy                           0.94     25976
#    macro avg       0.94      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976
#
# Model: ada_boosting
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93     14690
#            1       0.92      0.89      0.90     11286
#
#     accuracy                           0.92     25976
#    macro avg       0.92      0.91      0.91     25976
# weighted avg       0.92      0.92      0.92     25976
# c:\Users\aboys\Documents\Simplon\Machine Learning\Brief_Plane\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] Le fichier spécifié est introuvable
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\aboys\Documents\Simplon\Machine Learning\Brief_Plane\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\aboys\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aboys\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\aboys\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Model: hist_gradient_boosting
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     14690
#            1       0.97      0.94      0.96     11286
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %% [markdown]
# ### 2. Optimisation des modèles avec GridSearchCV

# %%
# Configurer les grilles de recherche pour chaque modèle
param_grids = {
    "logistic_regression": {"classifier__C": [0.1, 1, 10]},
    "naive_bayes": {},  # Pas d'hyperparamètres pour GaussianNB
    "random_forest": {"classifier__n_estimators": [100, 200],
                      "classifier__max_depth": [5, 10]},
    "gradient_boosting": {"classifier__learning_rate": [0.01, 0.1],
                          "classifier__n_estimators": [100, 200]},
    "ada_boosting": {
        "classifier__n_estimators": [50, 100, 200],
        "classifier__learning_rate": [0.01, 0.1, 1]
    },
    "hist_gradient_boosting": {
        "classifier__learning_rate": [0.01, 0.1, 0.2],
        "classifier__max_iter": [100, 200],
        "classifier__max_depth": [3, 5, None]
    }
}

# Optimiser les modèles
optimized_results = {}
best_models = {}

for name, pipeline in models.items():
    grid_search = GridSearchCV(pipeline, param_grids[name], cv=5, scoring="accuracy")
    grid_search.fit(X_train, y_train)
    best_models[name] = grid_search.best_estimator_
    optimized_results[name] = grid_search.best_score_

    print(f"Best parameters for {name}: {grid_search.best_params_}")
    print(f"Optimized Accuracy: {grid_search.best_score_}")
# Out:
# Best parameters for logistic_regression: {'classifier__C': 1}
# Optimized Accuracy: 0.8743070600277638
# Best parameters for naive_bayes: {}
# Optimized Accuracy: 0.8606405917265711
# Best parameters for random_forest: {'classifier__max_depth': 10, 'classifier__n_estimators': 100}
# Optimized Accuracy: 0.9454785329699119
# Best parameters for gradient_boosting: {'classifier__learning_rate': 0.1, 'classifier__n_estimators': 200}
# Optimized Accuracy: 0.9517439233726632
# Best parameters for ada_boosting: {'classifier__learning_rate': 1, 'classifier__n_estimators': 200}
# Optimized Accuracy: 0.9268170622466967
# Best parameters for hist_gradient_boosting: {'classifier__learning_rate': 0.1, 'classifier__max_depth': None, 'classifier__max_iter': 200}
# Optimized Accuracy: 0.9645345800855791

# %% [markdown]
# ### 3. Comparer les performances avant et après optimisation

# %%
# Comparer les performances avant et après optimisation
for name in models.keys():
    print(f"{name} - Initial Accuracy: {initial_results[name]:.4f}, Optimized Accuracy: {optimized_results.get(name, 'N/A'):.4f}")
# Out:
# logistic_regression - Initial Accuracy: 0.8744, Optimized Accuracy: 0.8743
# naive_bayes - Initial Accuracy: 0.8621, Optimized Accuracy: 0.8606
# random_forest - Initial Accuracy: 0.9615, Optimized Accuracy: 0.9455
# gradient_boosting - Initial Accuracy: 0.9388, Optimized Accuracy: 0.9517
# ada_boosting - Initial Accuracy: 0.9163, Optimized Accuracy: 0.9268
# hist_gradient_boosting - Initial Accuracy: 0.9621, Optimized Accuracy: 0.9645

# %% [markdown]
# ### 4. Vérification du surapprentissage/sous-apprentissage

# %%
from sklearn.model_selection import learning_curve
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curve(estimator, title, X, y, train_sizes=None, ylim=(0.1, 1.01), cv=5, n_jobs=-1):
    """
    Trace la courbe d'apprentissage pour un modèle donné.

    :param estimator: Modèle optimisé à évaluer.
    :param title: Titre de la courbe.
    :param X: Features d'entrée.
    :param y: Target.
    :param train_sizes: Liste des tailles d'échantillons d'entraînement (fractions ou nombres absolus).
    :param ylim: Limites des scores (axe y).
    :param cv: Nombre de folds pour la validation croisée.
    :param n_jobs: Nombre de jobs parallèles.
    """
    if train_sizes is None:
        train_sizes = [500, 1000, 2000, 3000, 4000, 5000, 10000, 20000, 30000]  # Tailles spécifiques

    # Limiter la taille maximale en fonction des données
    n_samples = len(X)
    train_sizes = [size for size in train_sizes if size <= n_samples]

    plt.figure(figsize=(10, 6))
    plt.title(title)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.ylim(*ylim)

    # Calcul des courbes d'apprentissage
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, train_sizes=train_sizes, cv=cv, n_jobs=n_jobs, scoring="accuracy"
    )

    # Moyenne et écart-type des scores
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    # Tracé des courbes avec les intervalles de confiance
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', label="Cross-validation score")

    plt.legend(loc="best")
    plt.grid()
    plt.show()

# Tracer les courbes pour les modèles optimisés
for name, model in best_models.items():
    plot_learning_curve(
        model, 
        f"Learning Curve: {name}", 
        X, 
        y, 
        train_sizes=[500, 1000, 2000, 3000, 4000, 5000, 10000, 20000, 30000], 
        ylim=(0.1, 1.01)
    )

# %%
import optuna
from sklearn.model_selection import cross_val_score

# Définir la fonction objectif pour Optuna
def objective(trial):
    # Paramètres à optimiser
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 1.0, log=True),
        "max_iter": trial.suggest_int("max_iter", 50, 1000),  # Equivalent de n_estimators
        "max_depth": trial.suggest_int("max_depth", 1, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 50),
        "l2_regularization": trial.suggest_float("l2_regularization", 0.0, 10.0),
        "max_bins": trial.suggest_int("max_bins", 32, 255),
        "early_stopping": trial.suggest_categorical("early_stopping", [True, False]),
    }

    # Modèle et pipeline
    model = Pipeline([
        ("preprocessor", preprocessor),
        ("classifier", HistGradientBoostingClassifier(random_state=42, **params))
    ])

    # Validation croisée
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring="accuracy", n_jobs=-1)
    return scores.mean()

# Étudier les hyperparamètres avec Optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=200)

# Meilleurs paramètres
print("Best hyperparameters:", study.best_params)
print("Best accuracy:", study.best_value)

# Entraîner et évaluer le meilleur modèle
best_params = study.best_params
best_model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", HistGradientBoostingClassifier(random_state=42, **best_params))
])

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# [I 2024-12-13 19:12:00,420] A new study created in memory with name: no-name-87bbe1c0-56af-4da0-a716-ff91268857c2
# [I 2024-12-13 19:12:05,733] Trial 0 finished with value: 0.9619264015460928 and parameters: {'learning_rate': 0.3823331518404681, 'max_iter': 198, 'max_depth': 10, 'min_samples_leaf': 6, 'l2_regularization': 0.6547051327788145, 'max_bins': 108, 'early_stopping': False}. Best is trial 0 with value: 0.9619264015460928.
# [I 2024-12-13 19:12:24,239] Trial 1 finished with value: 0.9597609401939907 and parameters: {'learning_rate': 0.006641412011128132, 'max_iter': 851, 'max_depth': 17, 'min_samples_leaf': 9, 'l2_regularization': 4.157215585340932, 'max_bins': 222, 'early_stopping': False}. Best is trial 0 with value: 0.9619264015460928.
# [I 2024-12-13 19:12:33,132] Trial 2 finished with value: 0.9254504213911622 and parameters: {'learning_rate': 0.017541860073309982, 'max_iter': 968, 'max_depth': 1, 'min_samples_leaf': 26, 'l2_regularization': 5.314681656876331, 'max_bins': 94, 'early_stopping': False}. Best is trial 0 with value: 0.9619264015460928.
# [I 2024-12-13 19:12:46,268] Trial 3 finished with value: 0.93846243137159 and parameters: {'learning_rate': 0.005588335800472138, 'max_iter': 488, 'max_depth': 5, 'min_samples_leaf': 21, 'l2_regularization': 4.509898861332165, 'max_bins': 189, 'early_stopping': True}. Best is trial 0 with value: 0.9619264015460928.
# [I 2024-12-13 19:13:17,528] Trial 4 finished with value: 0.9628503279931199 and parameters: {'learning_rate': 0.010121275675300443, 'max_iter': 913, 'max_depth': 15, 'min_samples_leaf': 46, 'l2_regularization': 7.2294188250765625, 'max_bins': 142, 'early_stopping': True}. Best is trial 4 with value: 0.9628503279931199.
# [I 2024-12-13 19:13:19,948] Trial 5 finished with value: 0.9617050454997044 and parameters: {'learning_rate': 0.5040403940088612, 'max_iter': 265, 'max_depth': 7, 'min_samples_leaf': 33, 'l2_regularization': 2.2254584914083955, 'max_bins': 175, 'early_stopping': True}. Best is trial 4 with value: 0.9628503279931199.
# [I 2024-12-13 19:13:34,343] Trial 6 finished with value: 0.9620033926378018 and parameters: {'learning_rate': 0.3648561186502426, 'max_iter': 594, 'max_depth': 13, 'min_samples_leaf': 2, 'l2_regularization': 9.336581220009187, 'max_bins': 129, 'early_stopping': False}. Best is trial 4 with value: 0.9628503279931199.
# [I 2024-12-13 19:13:54,109] Trial 7 finished with value: 0.9642747189988412 and parameters: {'learning_rate': 0.012918535749452197, 'max_iter': 997, 'max_depth': 19, 'min_samples_leaf': 10, 'l2_regularization': 1.3966997851112128, 'max_bins': 238, 'early_stopping': False}. Best is trial 7 with value: 0.9642747189988412.
# [I 2024-12-13 19:14:07,227] Trial 8 finished with value: 0.9424180246457639 and parameters: {'learning_rate': 0.0028730846377764446, 'max_iter': 711, 'max_depth': 6, 'min_samples_leaf': 34, 'l2_regularization': 3.798011740748084, 'max_bins': 142, 'early_stopping': False}. Best is trial 7 with value: 0.9642747189988412.
# [I 2024-12-13 19:14:18,265] Trial 9 finished with value: 0.9587503975530325 and parameters: {'learning_rate': 0.014336469942379656, 'max_iter': 631, 'max_depth': 6, 'min_samples_leaf': 17, 'l2_regularization': 4.725366916229998, 'max_bins': 247, 'early_stopping': False}. Best is trial 7 with value: 0.9642747189988412.
# [I 2024-12-13 19:14:24,823] Trial 10 finished with value: 0.9648618057723658 and parameters: {'learning_rate': 0.06594456451551962, 'max_iter': 402, 'max_depth': 20, 'min_samples_leaf': 50, 'l2_regularization': 0.15723797514504145, 'max_bins': 32, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:14:29,589] Trial 11 finished with value: 0.9644190922901504 and parameters: {'learning_rate': 0.10262467436053603, 'max_iter': 391, 'max_depth': 20, 'min_samples_leaf': 49, 'l2_regularization': 0.07691600317173641, 'max_bins': 32, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:14:35,276] Trial 12 finished with value: 0.9644094681142205 and parameters: {'learning_rate': 0.0943385467748131, 'max_iter': 379, 'max_depth': 20, 'min_samples_leaf': 50, 'l2_regularization': 0.1499881675757787, 'max_bins': 33, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:14:36,889] Trial 13 finished with value: 0.9541018742642635 and parameters: {'learning_rate': 0.062035891989842544, 'max_iter': 53, 'max_depth': 16, 'min_samples_leaf': 42, 'l2_regularization': 2.3059465969039894, 'max_bins': 33, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:14:40,867] Trial 14 finished with value: 0.9645634558553917 and parameters: {'learning_rate': 0.12897890032736328, 'max_iter': 421, 'max_depth': 20, 'min_samples_leaf': 38, 'l2_regularization': 2.4997414198189407, 'max_bins': 75, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:14:49,677] Trial 15 finished with value: 0.9645827005020827 and parameters: {'learning_rate': 0.04166028165386063, 'max_iter': 470, 'max_depth': 12, 'min_samples_leaf': 38, 'l2_regularization': 2.6058115864397493, 'max_bins': 72, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:14:55,160] Trial 16 finished with value: 0.9630716872815311 and parameters: {'learning_rate': 0.03907246256913258, 'max_iter': 259, 'max_depth': 11, 'min_samples_leaf': 43, 'l2_regularization': 6.2880351601289854, 'max_bins': 66, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:10,069] Trial 17 finished with value: 0.9425238739077336 and parameters: {'learning_rate': 0.0012435085269693125, 'max_iter': 773, 'max_depth': 10, 'min_samples_leaf': 29, 'l2_regularization': 2.8584465127106995, 'max_bins': 64, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:13,098] Trial 18 finished with value: 0.9640437475762985 and parameters: {'learning_rate': 0.2068989484777092, 'max_iter': 518, 'max_depth': 14, 'min_samples_leaf': 38, 'l2_regularization': 1.064558665896003, 'max_bins': 99, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:15,043] Trial 19 finished with value: 0.9344876115134231 and parameters: {'learning_rate': 0.9355900287798077, 'max_iter': 154, 'max_depth': 1, 'min_samples_leaf': 42, 'l2_regularization': 3.2819309145408266, 'max_bins': 60, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:21,493] Trial 20 finished with value: 0.9636010192734081 and parameters: {'learning_rate': 0.035904323239747696, 'max_iter': 315, 'max_depth': 12, 'min_samples_leaf': 37, 'l2_regularization': 1.5667818249330505, 'max_bins': 82, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:25,268] Trial 21 finished with value: 0.9646211967426565 and parameters: {'learning_rate': 0.15210062472252447, 'max_iter': 439, 'max_depth': 18, 'min_samples_leaf': 30, 'l2_regularization': 2.0756094866177923, 'max_bins': 55, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:33,634] Trial 22 finished with value: 0.9645442019457787 and parameters: {'learning_rate': 0.056275394547937875, 'max_iter': 466, 'max_depth': 18, 'min_samples_leaf': 29, 'l2_regularization': 1.5940281052466245, 'max_bins': 53, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:36,736] Trial 23 finished with value: 0.9641496028591676 and parameters: {'learning_rate': 0.1980391729735585, 'max_iter': 597, 'max_depth': 17, 'min_samples_leaf': 22, 'l2_regularization': 0.9026607775393809, 'max_bins': 49, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:44,337] Trial 24 finished with value: 0.9629850683087234 and parameters: {'learning_rate': 0.025636565366862783, 'max_iter': 350, 'max_depth': 18, 'min_samples_leaf': 33, 'l2_regularization': 3.1886122729475446, 'max_bins': 115, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:48,325] Trial 25 finished with value: 0.9644479574076026 and parameters: {'learning_rate': 0.1780032892938577, 'max_iter': 676, 'max_depth': 15, 'min_samples_leaf': 46, 'l2_regularization': 1.915871191781169, 'max_bins': 86, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:15:57,793] Trial 26 finished with value: 0.964515329881135 and parameters: {'learning_rate': 0.054686780025345966, 'max_iter': 573, 'max_depth': 9, 'min_samples_leaf': 29, 'l2_regularization': 9.655191700905439, 'max_bins': 49, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:16:07,119] Trial 27 finished with value: 0.9631775546061986 and parameters: {'learning_rate': 0.02277403198642762, 'max_iter': 446, 'max_depth': 13, 'min_samples_leaf': 16, 'l2_regularization': 5.604463066341582, 'max_bins': 75, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:16:13,055] Trial 28 finished with value: 0.9648521783544132 and parameters: {'learning_rate': 0.08680239906050025, 'max_iter': 533, 'max_depth': 18, 'min_samples_leaf': 46, 'l2_regularization': 3.5072826319465085, 'max_bins': 167, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:16:14,909] Trial 29 finished with value: 0.9633507994990056 and parameters: {'learning_rate': 0.30449267193623747, 'max_iter': 178, 'max_depth': 18, 'min_samples_leaf': 47, 'l2_regularization': 0.6540239582901042, 'max_bins': 173, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:16:21,577] Trial 30 finished with value: 0.9646693213274748 and parameters: {'learning_rate': 0.07968495767925769, 'max_iter': 526, 'max_depth': 16, 'min_samples_leaf': 43, 'l2_regularization': 3.4563619826644123, 'max_bins': 161, 'early_stopping': True}. Best is trial 10 with value: 0.9648618057723658.
# [I 2024-12-13 19:16:28,426] Trial 31 finished with value: 0.9649580433633502 and parameters: {'learning_rate': 0.08005808379959835, 'max_iter': 556, 'max_depth': 16, 'min_samples_leaf': 44, 'l2_regularization': 3.6751090510156774, 'max_bins': 161, 'early_stopping': True}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:16:35,501] Trial 32 finished with value: 0.964630824623755 and parameters: {'learning_rate': 0.07585217899734457, 'max_iter': 534, 'max_depth': 16, 'min_samples_leaf': 44, 'l2_regularization': 3.679615025513816, 'max_bins': 163, 'early_stopping': True}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:16:40,485] Trial 33 finished with value: 0.9644383327685266 and parameters: {'learning_rate': 0.09611358073234334, 'max_iter': 771, 'max_depth': 16, 'min_samples_leaf': 50, 'l2_regularization': 6.256454665755464, 'max_bins': 197, 'early_stopping': True}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:16:49,755] Trial 34 finished with value: 0.9627059727645084 and parameters: {'learning_rate': 0.26995056350179086, 'max_iter': 550, 'max_depth': 19, 'min_samples_leaf': 41, 'l2_regularization': 4.2474161274899025, 'max_bins': 208, 'early_stopping': False}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:17:02,804] Trial 35 finished with value: 0.964101481979518 and parameters: {'learning_rate': 0.022843012002767414, 'max_iter': 652, 'max_depth': 17, 'min_samples_leaf': 47, 'l2_regularization': 7.921809179898575, 'max_bins': 159, 'early_stopping': True}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:17:04,378] Trial 36 finished with value: 0.9628695721766649 and parameters: {'learning_rate': 0.5401959704751511, 'max_iter': 726, 'max_depth': 15, 'min_samples_leaf': 45, 'l2_regularization': 3.9123933238813255, 'max_bins': 123, 'early_stopping': True}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:17:12,829] Trial 37 finished with value: 0.9647944374671485 and parameters: {'learning_rate': 0.07089884815970803, 'max_iter': 512, 'max_depth': 19, 'min_samples_leaf': 40, 'l2_regularization': 5.1635057496517005, 'max_bins': 155, 'early_stopping': False}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:17:19,498] Trial 38 finished with value: 0.9493956105513759 and parameters: {'learning_rate': 0.00739292028005325, 'max_iter': 323, 'max_depth': 19, 'min_samples_leaf': 40, 'l2_regularization': 5.24388543481604, 'max_bins': 185, 'early_stopping': False}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:17:24,860] Trial 39 finished with value: 0.9639667458322293 and parameters: {'learning_rate': 0.051010087462758626, 'max_iter': 264, 'max_depth': 19, 'min_samples_leaf': 48, 'l2_regularization': 5.6898155895367335, 'max_bins': 149, 'early_stopping': False}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:17:35,836] Trial 40 finished with value: 0.9646404469471006 and parameters: {'learning_rate': 0.02896407078867487, 'max_iter': 613, 'max_depth': 20, 'min_samples_leaf': 46, 'l2_regularization': 7.157828619115309, 'max_bins': 133, 'early_stopping': False}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:17:44,413] Trial 41 finished with value: 0.9648906778370095 and parameters: {'learning_rate': 0.0764646089004988, 'max_iter': 530, 'max_depth': 17, 'min_samples_leaf': 35, 'l2_regularization': 4.9305757620572015, 'max_bins': 159, 'early_stopping': False}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:17:52,371] Trial 42 finished with value: 0.9643613449188402 and parameters: {'learning_rate': 0.13308965193721672, 'max_iter': 498, 'max_depth': 17, 'min_samples_leaf': 34, 'l2_regularization': 4.674849357055352, 'max_bins': 175, 'early_stopping': False}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:17:58,854] Trial 43 finished with value: 0.9644672094646314 and parameters: {'learning_rate': 0.11982976894141717, 'max_iter': 408, 'max_depth': 18, 'min_samples_leaf': 36, 'l2_regularization': 4.926008125053332, 'max_bins': 151, 'early_stopping': False}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:18:12,348] Trial 44 finished with value: 0.9648425551047755 and parameters: {'learning_rate': 0.06590351368766141, 'max_iter': 887, 'max_depth': 14, 'min_samples_leaf': 40, 'l2_regularization': 6.567587038431844, 'max_bins': 209, 'early_stopping': False}. Best is trial 31 with value: 0.9649580433633502.
# [I 2024-12-13 19:18:26,602] Trial 45 finished with value: 0.9649965363619012 and parameters: {'learning_rate': 0.04510113490669709, 'max_iter': 854, 'max_depth': 14, 'min_samples_leaf': 44, 'l2_regularization': 8.482149089233726, 'max_bins': 224, 'early_stopping': False}. Best is trial 45 with value: 0.9649965363619012.
# [I 2024-12-13 19:18:42,031] Trial 46 finished with value: 0.9643517124062806 and parameters: {'learning_rate': 0.019622874670146898, 'max_iter': 825, 'max_depth': 14, 'min_samples_leaf': 50, 'l2_regularization': 9.136768748363702, 'max_bins': 224, 'early_stopping': False}. Best is trial 45 with value: 0.9649965363619012.
# [I 2024-12-13 19:18:58,840] Trial 47 finished with value: 0.9642362204425371 and parameters: {'learning_rate': 0.014007389701047963, 'max_iter': 952, 'max_depth': 15, 'min_samples_leaf': 44, 'l2_regularization': 4.351117398763065, 'max_bins': 138, 'early_stopping': False}. Best is trial 45 with value: 0.9649965363619012.
# [I 2024-12-13 19:19:11,193] Trial 48 finished with value: 0.9643517179640337 and parameters: {'learning_rate': 0.03464406065350406, 'max_iter': 695, 'max_depth': 8, 'min_samples_leaf': 48, 'l2_regularization': 8.280214988062214, 'max_bins': 254, 'early_stopping': False}. Best is trial 45 with value: 0.9649965363619012.
# [I 2024-12-13 19:19:24,203] Trial 49 finished with value: 0.964842553252191 and parameters: {'learning_rate': 0.04183632112359825, 'max_iter': 825, 'max_depth': 17, 'min_samples_leaf': 35, 'l2_regularization': 2.984452078404619, 'max_bins': 190, 'early_stopping': False}. Best is trial 45 with value: 0.9649965363619012.
# [I 2024-12-13 19:19:33,356] Trial 50 finished with value: 0.964255474815296 and parameters: {'learning_rate': 0.10281874821223398, 'max_iter': 578, 'max_depth': 13, 'min_samples_leaf': 7, 'l2_regularization': 5.843527826230465, 'max_bins': 221, 'early_stopping': False}. Best is trial 45 with value: 0.9649965363619012.
# [I 2024-12-13 19:19:47,863] Trial 51 finished with value: 0.9648906759844251 and parameters: {'learning_rate': 0.05106847655904571, 'max_iter': 910, 'max_depth': 15, 'min_samples_leaf': 40, 'l2_regularization': 6.9353111814430415, 'max_bins': 207, 'early_stopping': False}. Best is trial 45 with value: 0.9649965363619012.
# [I 2024-12-13 19:19:58,363] Trial 52 finished with value: 0.956180712475243 and parameters: {'learning_rate': 0.04494634602029619, 'max_iter': 929, 'max_depth': 3, 'min_samples_leaf': 45, 'l2_regularization': 7.822966769585319, 'max_bins': 239, 'early_stopping': False}. Best is trial 45 with value: 0.9649965363619012.
# [I 2024-12-13 19:20:12,429] Trial 53 finished with value: 0.9639378765464622 and parameters: {'learning_rate': 0.08370892626483402, 'max_iter': 896, 'max_depth': 15, 'min_samples_leaf': 32, 'l2_regularization': 8.881871575349805, 'max_bins': 227, 'early_stopping': False}. Best is trial 45 with value: 0.9649965363619012.
# [I 2024-12-13 19:20:25,306] Trial 54 finished with value: 0.9650927869209764 and parameters: {'learning_rate': 0.03310544455558417, 'max_iter': 746, 'max_depth': 16, 'min_samples_leaf': 25, 'l2_regularization': 7.144238529573173, 'max_bins': 206, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:20:41,756] Trial 55 finished with value: 0.9627444657630594 and parameters: {'learning_rate': 0.010898074970054256, 'max_iter': 863, 'max_depth': 12, 'min_samples_leaf': 23, 'l2_regularization': 7.028791910530899, 'max_bins': 208, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:20:56,878] Trial 56 finished with value: 0.9645923237517205 and parameters: {'learning_rate': 0.05530343982566098, 'max_iter': 984, 'max_depth': 14, 'min_samples_leaf': 25, 'l2_regularization': 8.486629055332342, 'max_bins': 187, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:21:11,459] Trial 57 finished with value: 0.9638320045903337 and parameters: {'learning_rate': 0.016767657883924706, 'max_iter': 780, 'max_depth': 11, 'min_samples_leaf': 18, 'l2_regularization': 6.680349272115632, 'max_bins': 199, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:21:25,639] Trial 58 finished with value: 0.9650542860489418 and parameters: {'learning_rate': 0.03350647641511303, 'max_iter': 824, 'max_depth': 16, 'min_samples_leaf': 27, 'l2_regularization': 7.9175629493545845, 'max_bins': 217, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:21:38,441] Trial 59 finished with value: 0.9649580438264964 and parameters: {'learning_rate': 0.029774964397298057, 'max_iter': 733, 'max_depth': 16, 'min_samples_leaf': 26, 'l2_regularization': 7.544012658794134, 'max_bins': 234, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:21:51,178] Trial 60 finished with value: 0.9650927841421 and parameters: {'learning_rate': 0.031334523519607034, 'max_iter': 739, 'max_depth': 16, 'min_samples_leaf': 25, 'l2_regularization': 7.545842269538774, 'max_bins': 235, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:22:04,460] Trial 61 finished with value: 0.9649099229468467 and parameters: {'learning_rate': 0.02922679707185407, 'max_iter': 748, 'max_depth': 16, 'min_samples_leaf': 25, 'l2_regularization': 7.529340627346982, 'max_bins': 236, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:22:17,536] Trial 62 finished with value: 0.9648329304656993 and parameters: {'learning_rate': 0.030226723965947062, 'max_iter': 749, 'max_depth': 16, 'min_samples_leaf': 27, 'l2_regularization': 7.564668753685685, 'max_bins': 234, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:22:32,387] Trial 63 finished with value: 0.9645538261217086 and parameters: {'learning_rate': 0.019601660344418573, 'max_iter': 811, 'max_depth': 16, 'min_samples_leaf': 20, 'l2_regularization': 8.517436404041197, 'max_bins': 245, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:22:47,249] Trial 64 finished with value: 0.9601266621213508 and parameters: {'learning_rate': 0.008056160312351164, 'max_iter': 732, 'max_depth': 14, 'min_samples_leaf': 24, 'l2_regularization': 7.492485286270264, 'max_bins': 232, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:22:59,623] Trial 65 finished with value: 0.9646693166960139 and parameters: {'learning_rate': 0.02733472535238195, 'max_iter': 665, 'max_depth': 15, 'min_samples_leaf': 27, 'l2_regularization': 8.206684619754649, 'max_bins': 218, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:23:17,160] Trial 66 finished with value: 0.9575281096103788 and parameters: {'learning_rate': 0.005242222859059794, 'max_iter': 857, 'max_depth': 13, 'min_samples_leaf': 13, 'l2_regularization': 7.483506229740703, 'max_bins': 254, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:23:30,473] Trial 67 finished with value: 0.9647078129365875 and parameters: {'learning_rate': 0.035502951032921955, 'max_iter': 787, 'max_depth': 16, 'min_samples_leaf': 21, 'l2_regularization': 9.784017196826156, 'max_bins': 216, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:23:44,716] Trial 68 finished with value: 0.9638416329345784 and parameters: {'learning_rate': 0.015785796961822158, 'max_iter': 701, 'max_depth': 17, 'min_samples_leaf': 31, 'l2_regularization': 8.770396704814452, 'max_bins': 244, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:23:56,825] Trial 69 finished with value: 0.9640726099148742 and parameters: {'learning_rate': 0.02302001951976238, 'max_iter': 635, 'max_depth': 14, 'min_samples_leaf': 26, 'l2_regularization': 8.01262548565059, 'max_bins': 228, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:24:09,931] Trial 70 finished with value: 0.9649965456248232 and parameters: {'learning_rate': 0.031542058994473925, 'max_iter': 750, 'max_depth': 17, 'min_samples_leaf': 28, 'l2_regularization': 6.183603326806011, 'max_bins': 237, 'early_stopping': False}. Best is trial 54 with value: 0.9650927869209764.
# [I 2024-12-13 19:24:22,574] Trial 71 finished with value: 0.9651794017254692 and parameters: {'learning_rate': 0.0424268870983314, 'max_iter': 741, 'max_depth': 17, 'min_samples_leaf': 28, 'l2_regularization': 7.734928899931385, 'max_bins': 234, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:24:35,444] Trial 72 finished with value: 0.9647655626236281 and parameters: {'learning_rate': 0.04313743420396511, 'max_iter': 820, 'max_depth': 18, 'min_samples_leaf': 28, 'l2_regularization': 6.297378984113468, 'max_bins': 241, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:24:49,325] Trial 73 finished with value: 0.9622440030569497 and parameters: {'learning_rate': 0.011572068093933553, 'max_iter': 682, 'max_depth': 17, 'min_samples_leaf': 19, 'l2_regularization': 6.848799905714817, 'max_bins': 199, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:25:03,455] Trial 74 finished with value: 0.9647944295936648 and parameters: {'learning_rate': 0.03511538443639227, 'max_iter': 802, 'max_depth': 16, 'min_samples_leaf': 23, 'l2_regularization': 9.31321054254786, 'max_bins': 214, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:25:15,722] Trial 75 finished with value: 0.9648618034566354 and parameters: {'learning_rate': 0.06156283404751602, 'max_iter': 753, 'max_depth': 17, 'min_samples_leaf': 30, 'l2_regularization': 7.200129890452688, 'max_bins': 248, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:25:35,219] Trial 76 finished with value: 0.9643420914723734 and parameters: {'learning_rate': 0.018982547369263955, 'max_iter': 717, 'max_depth': 18, 'min_samples_leaf': 16, 'l2_regularization': 7.780050077665549, 'max_bins': 231, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:25:55,935] Trial 77 finished with value: 0.96508315996617 and parameters: {'learning_rate': 0.045105409081272335, 'max_iter': 841, 'max_depth': 15, 'min_samples_leaf': 28, 'l2_regularization': 6.300781399354883, 'max_bins': 224, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:26:18,748] Trial 78 finished with value: 0.964832928613115 and parameters: {'learning_rate': 0.024498967074244687, 'max_iter': 845, 'max_depth': 13, 'min_samples_leaf': 27, 'l2_regularization': 6.159850412239325, 'max_bins': 224, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:26:40,716] Trial 79 finished with value: 0.9645538228796859 and parameters: {'learning_rate': 0.04426009666508803, 'max_iter': 881, 'max_depth': 15, 'min_samples_leaf': 31, 'l2_regularization': 6.47038015215695, 'max_bins': 250, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:27:02,511] Trial 80 finished with value: 0.9651601459632719 and parameters: {'learning_rate': 0.034780593772901415, 'max_iter': 847, 'max_depth': 14, 'min_samples_leaf': 23, 'l2_regularization': 7.340403777161633, 'max_bins': 213, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:27:26,407] Trial 81 finished with value: 0.9649965433090927 and parameters: {'learning_rate': 0.032097308018088674, 'max_iter': 928, 'max_depth': 14, 'min_samples_leaf': 22, 'l2_regularization': 8.060219483607536, 'max_bins': 214, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:27:50,072] Trial 82 finished with value: 0.96506391161431 and parameters: {'learning_rate': 0.03807939246709929, 'max_iter': 943, 'max_depth': 14, 'min_samples_leaf': 22, 'l2_regularization': 6.009653622441372, 'max_bins': 214, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:28:14,005] Trial 83 finished with value: 0.9651505324397022 and parameters: {'learning_rate': 0.03691226013834747, 'max_iter': 951, 'max_depth': 13, 'min_samples_leaf': 22, 'l2_regularization': 5.943460339564762, 'max_bins': 214, 'early_stopping': False}. Best is trial 71 with value: 0.9651794017254692.
# [I 2024-12-13 19:28:38,835] Trial 84 finished with value: 0.9651986556350824 and parameters: {'learning_rate': 0.038892341872598046, 'max_iter': 990, 'max_depth': 13, 'min_samples_leaf': 23, 'l2_regularization': 5.720943212090619, 'max_bins': 202, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:29:02,045] Trial 85 finished with value: 0.9648714276325652 and parameters: {'learning_rate': 0.05087580936152967, 'max_iter': 958, 'max_depth': 12, 'min_samples_leaf': 24, 'l2_regularization': 5.6131872403231275, 'max_bins': 196, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:29:26,623] Trial 86 finished with value: 0.96507353579024 and parameters: {'learning_rate': 0.0383307889017179, 'max_iter': 993, 'max_depth': 11, 'min_samples_leaf': 20, 'l2_regularization': 5.982304921932847, 'max_bins': 204, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:29:50,413] Trial 87 finished with value: 0.9647848132912186 and parameters: {'learning_rate': 0.039484530772519864, 'max_iter': 973, 'max_depth': 10, 'min_samples_leaf': 21, 'l2_regularization': 5.975735262718075, 'max_bins': 203, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:30:07,598] Trial 88 finished with value: 0.9643035966212381 and parameters: {'learning_rate': 0.06575673908284217, 'max_iter': 990, 'max_depth': 11, 'min_samples_leaf': 14, 'l2_regularization': 6.774487143586492, 'max_bins': 193, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:30:23,833] Trial 89 finished with value: 0.9649291712987065 and parameters: {'learning_rate': 0.021323581356683715, 'max_iter': 950, 'max_depth': 12, 'min_samples_leaf': 19, 'l2_regularization': 5.545444985189644, 'max_bins': 180, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:30:39,419] Trial 90 finished with value: 0.9646981869080731 and parameters: {'learning_rate': 0.025697761889379243, 'max_iter': 936, 'max_depth': 9, 'min_samples_leaf': 22, 'l2_regularization': 5.43149018396029, 'max_bins': 203, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:30:53,109] Trial 91 finished with value: 0.9649484196505664 and parameters: {'learning_rate': 0.052434276193316975, 'max_iter': 911, 'max_depth': 13, 'min_samples_leaf': 24, 'l2_regularization': 5.9319340499027104, 'max_bins': 212, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:31:06,985] Trial 92 finished with value: 0.9651890282171298 and parameters: {'learning_rate': 0.038760331149953774, 'max_iter': 873, 'max_depth': 13, 'min_samples_leaf': 20, 'l2_regularization': 6.407356066585174, 'max_bins': 220, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:31:21,172] Trial 93 finished with value: 0.9651312813089656 and parameters: {'learning_rate': 0.03972035215833939, 'max_iter': 877, 'max_depth': 11, 'min_samples_leaf': 17, 'l2_regularization': 6.495092327780034, 'max_bins': 220, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:31:35,244] Trial 94 finished with value: 0.9646596939095223 and parameters: {'learning_rate': 0.049184228983845404, 'max_iter': 892, 'max_depth': 11, 'min_samples_leaf': 14, 'l2_regularization': 6.434899289750123, 'max_bins': 219, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:31:48,882] Trial 95 finished with value: 0.9645057084840815 and parameters: {'learning_rate': 0.05999995147211265, 'max_iter': 868, 'max_depth': 10, 'min_samples_leaf': 20, 'l2_regularization': 7.274609834035175, 'max_bins': 203, 'early_stopping': False}. Best is trial 84 with value: 0.9651986556350824.
# [I 2024-12-13 19:32:04,026] Trial 96 finished with value: 0.9652179007449195 and parameters: {'learning_rate': 0.039140848238003866, 'max_iter': 973, 'max_depth': 12, 'min_samples_leaf': 1, 'l2_regularization': 6.627751042548457, 'max_bins': 228, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:32:20,801] Trial 97 finished with value: 0.9448433382848282 and parameters: {'learning_rate': 0.0013734755123586061, 'max_iter': 845, 'max_depth': 12, 'min_samples_leaf': 12, 'l2_regularization': 6.593555840540536, 'max_bins': 226, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:32:36,704] Trial 98 finished with value: 0.9651312813089656 and parameters: {'learning_rate': 0.02557793112323376, 'max_iter': 965, 'max_depth': 13, 'min_samples_leaf': 1, 'l2_regularization': 6.921547781586346, 'max_bins': 229, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:32:53,633] Trial 99 finished with value: 0.9644094648721978 and parameters: {'learning_rate': 0.01657366954318763, 'max_iter': 913, 'max_depth': 13, 'min_samples_leaf': 2, 'l2_regularization': 7.0463720057051, 'max_bins': 242, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:33:09,882] Trial 100 finished with value: 0.9648040565484713 and parameters: {'learning_rate': 0.025418309694882416, 'max_iter': 973, 'max_depth': 12, 'min_samples_leaf': 1, 'l2_regularization': 6.8503106921975965, 'max_bins': 230, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:33:25,126] Trial 101 finished with value: 0.9648906787633017 and parameters: {'learning_rate': 0.0457536108857181, 'max_iter': 1000, 'max_depth': 13, 'min_samples_leaf': 6, 'l2_regularization': 6.345558084083933, 'max_bins': 222, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:33:39,549] Trial 102 finished with value: 0.9650350386233741 and parameters: {'learning_rate': 0.03922392642090817, 'max_iter': 873, 'max_depth': 13, 'min_samples_leaf': 4, 'l2_regularization': 6.6448852153846225, 'max_bins': 210, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:33:55,332] Trial 103 finished with value: 0.9651697831072926 and parameters: {'learning_rate': 0.02813724033143418, 'max_iter': 927, 'max_depth': 12, 'min_samples_leaf': 17, 'l2_regularization': 7.292470890640294, 'max_bins': 222, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:34:13,768] Trial 104 finished with value: 0.9640822410379956 and parameters: {'learning_rate': 0.014186834108322001, 'max_iter': 966, 'max_depth': 12, 'min_samples_leaf': 17, 'l2_regularization': 7.780709387551497, 'max_bins': 230, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:34:29,959] Trial 105 finished with value: 0.9646115734930186 and parameters: {'learning_rate': 0.020156486185174422, 'max_iter': 901, 'max_depth': 11, 'min_samples_leaf': 3, 'l2_regularization': 7.260918316748878, 'max_bins': 221, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:34:45,406] Trial 106 finished with value: 0.964871431337734 and parameters: {'learning_rate': 0.027353218196541903, 'max_iter': 928, 'max_depth': 9, 'min_samples_leaf': 9, 'l2_regularization': 7.32625017294574, 'max_bins': 238, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:34:59,123] Trial 107 finished with value: 0.9649965423828005 and parameters: {'learning_rate': 0.03201450415127314, 'max_iter': 790, 'max_depth': 12, 'min_samples_leaf': 18, 'l2_regularization': 7.041087058382956, 'max_bins': 233, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:35:15,706] Trial 108 finished with value: 0.9649002983077708 and parameters: {'learning_rate': 0.022202947363718063, 'max_iter': 961, 'max_depth': 13, 'min_samples_leaf': 4, 'l2_regularization': 5.736961610098472, 'max_bins': 217, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:35:30,180] Trial 109 finished with value: 0.964794430519957 and parameters: {'learning_rate': 0.05721271283909601, 'max_iter': 933, 'max_depth': 11, 'min_samples_leaf': 23, 'l2_regularization': 7.6843195933736475, 'max_bins': 210, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:35:43,898] Trial 110 finished with value: 0.964207351619916 and parameters: {'learning_rate': 0.07232784793222635, 'max_iter': 918, 'max_depth': 14, 'min_samples_leaf': 25, 'l2_regularization': 5.07036997293873, 'max_bins': 183, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:35:58,394] Trial 111 finished with value: 0.9649772931046485 and parameters: {'learning_rate': 0.03571149548910733, 'max_iter': 876, 'max_depth': 15, 'min_samples_leaf': 26, 'l2_regularization': 6.702693216185155, 'max_bins': 227, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:36:12,780] Trial 112 finished with value: 0.9650157888820761 and parameters: {'learning_rate': 0.027246223672676734, 'max_iter': 840, 'max_depth': 13, 'min_samples_leaf': 23, 'l2_regularization': 6.147987465073444, 'max_bins': 223, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:36:25,221] Trial 113 finished with value: 0.9650254163000286 and parameters: {'learning_rate': 0.04719509279026697, 'max_iter': 771, 'max_depth': 15, 'min_samples_leaf': 28, 'l2_regularization': 6.511458844552319, 'max_bins': 220, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:36:41,015] Trial 114 finished with value: 0.96506391161431 and parameters: {'learning_rate': 0.040725922986408786, 'max_iter': 980, 'max_depth': 14, 'min_samples_leaf': 15, 'l2_regularization': 6.91371307488277, 'max_bins': 250, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:36:55,445] Trial 115 finished with value: 0.9650446627993041 and parameters: {'learning_rate': 0.03171604265189626, 'max_iter': 888, 'max_depth': 12, 'min_samples_leaf': 29, 'l2_regularization': 7.297210506724533, 'max_bins': 241, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:36:57,560] Trial 116 finished with value: 0.9471050325964541 and parameters: {'learning_rate': 0.023659203499512622, 'max_iter': 74, 'max_depth': 15, 'min_samples_leaf': 21, 'l2_regularization': 5.344523439777797, 'max_bins': 206, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:37:12,086] Trial 117 finished with value: 0.9650831595030238 and parameters: {'learning_rate': 0.028411010395169113, 'max_iter': 835, 'max_depth': 12, 'min_samples_leaf': 11, 'l2_regularization': 7.051590557905885, 'max_bins': 236, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:37:26,937] Trial 118 finished with value: 0.9642266013612142 and parameters: {'learning_rate': 0.017688951664775184, 'max_iter': 808, 'max_depth': 14, 'min_samples_leaf': 24, 'l2_regularization': 7.409286208177798, 'max_bins': 227, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:37:41,769] Trial 119 finished with value: 0.9646211925743415 and parameters: {'learning_rate': 0.06089589169178266, 'max_iter': 946, 'max_depth': 13, 'min_samples_leaf': 18, 'l2_regularization': 6.350285284068081, 'max_bins': 212, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:37:56,755] Trial 120 finished with value: 0.9650927832158077 and parameters: {'learning_rate': 0.03499040680948201, 'max_iter': 899, 'max_depth': 14, 'min_samples_leaf': 25, 'l2_regularization': 8.138735240322061, 'max_bins': 192, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:38:11,437] Trial 121 finished with value: 0.9649387959377826 and parameters: {'learning_rate': 0.035753823672509295, 'max_iter': 900, 'max_depth': 14, 'min_samples_leaf': 25, 'l2_regularization': 8.270559406553797, 'max_bins': 190, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:38:25,470] Trial 122 finished with value: 0.9650542883646723 and parameters: {'learning_rate': 0.04317992553547768, 'max_iter': 859, 'max_depth': 15, 'min_samples_leaf': 1, 'l2_regularization': 8.102123158590073, 'max_bins': 196, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:38:41,570] Trial 123 finished with value: 0.9650061688744611 and parameters: {'learning_rate': 0.031490900717445175, 'max_iter': 957, 'max_depth': 13, 'min_samples_leaf': 19, 'l2_regularization': 7.62155253875377, 'max_bins': 218, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:38:55,447] Trial 124 finished with value: 0.9649195499016532 and parameters: {'learning_rate': 0.051943070474853775, 'max_iter': 913, 'max_depth': 12, 'min_samples_leaf': 26, 'l2_regularization': 6.786425183335081, 'max_bins': 232, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:39:11,475] Trial 125 finished with value: 0.965083160429316 and parameters: {'learning_rate': 0.037091428493650255, 'max_iter': 998, 'max_depth': 14, 'min_samples_leaf': 8, 'l2_regularization': 5.840102594083805, 'max_bins': 201, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:39:28,275] Trial 126 finished with value: 0.9650639120774562 and parameters: {'learning_rate': 0.02483702801757904, 'max_iter': 996, 'max_depth': 11, 'min_samples_leaf': 6, 'l2_regularization': 5.732350950789751, 'max_bins': 200, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:39:43,133] Trial 127 finished with value: 0.9632256787278711 and parameters: {'learning_rate': 0.038109868487155536, 'max_iter': 974, 'max_depth': 5, 'min_samples_leaf': 9, 'l2_regularization': 4.739325406299162, 'max_bins': 194, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:39:59,232] Trial 128 finished with value: 0.9647463119560378 and parameters: {'learning_rate': 0.021925112208244675, 'max_iter': 943, 'max_depth': 10, 'min_samples_leaf': 3, 'l2_regularization': 7.9197586691406165, 'max_bins': 103, 'early_stopping': False}. Best is trial 96 with value: 0.9652179007449195.
# [I 2024-12-13 19:40:14,535] Trial 129 finished with value: 0.9653045224966039 and parameters: {'learning_rate': 0.03400676560252863, 'max_iter': 925, 'max_depth': 13, 'min_samples_leaf': 16, 'l2_regularization': 8.763352346928274, 'max_bins': 209, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:40:29,839] Trial 130 finished with value: 0.9649099294308922 and parameters: {'learning_rate': 0.028301626948871256, 'max_iter': 886, 'max_depth': 13, 'min_samples_leaf': 16, 'l2_regularization': 8.66091470984826, 'max_bins': 207, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:40:45,130] Trial 131 finished with value: 0.9649002983077706 and parameters: {'learning_rate': 0.03373112087378428, 'max_iter': 922, 'max_depth': 13, 'min_samples_leaf': 17, 'l2_regularization': 8.268623146984853, 'max_bins': 213, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:41:01,448] Trial 132 finished with value: 0.9649869223751855 and parameters: {'learning_rate': 0.03967535813735228, 'max_iter': 975, 'max_depth': 14, 'min_samples_leaf': 22, 'l2_regularization': 9.129104808737337, 'max_bins': 201, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:41:17,391] Trial 133 finished with value: 0.9649387917694676 and parameters: {'learning_rate': 0.04950659002544984, 'max_iter': 1000, 'max_depth': 12, 'min_samples_leaf': 7, 'l2_regularization': 8.953106049392755, 'max_bins': 207, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:41:33,349] Trial 134 finished with value: 0.96516015568934 and parameters: {'learning_rate': 0.03043149944812512, 'max_iter': 943, 'max_depth': 13, 'min_samples_leaf': 20, 'l2_regularization': 6.118054035536059, 'max_bins': 217, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:41:50,508] Trial 135 finished with value: 0.9646211930374877 and parameters: {'learning_rate': 0.019228792685978775, 'max_iter': 947, 'max_depth': 13, 'min_samples_leaf': 21, 'l2_regularization': 7.131255689615992, 'max_bins': 215, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:42:06,059] Trial 136 finished with value: 0.9649869168174323 and parameters: {'learning_rate': 0.029580447187215194, 'max_iter': 903, 'max_depth': 12, 'min_samples_leaf': 19, 'l2_regularization': 6.102202312812313, 'max_bins': 218, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:42:22,193] Trial 137 finished with value: 0.9649099238731388 and parameters: {'learning_rate': 0.025102064684503312, 'max_iter': 927, 'max_depth': 13, 'min_samples_leaf': 20, 'l2_regularization': 6.579136453569035, 'max_bins': 230, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:42:36,475] Trial 138 finished with value: 0.9650927855315382 and parameters: {'learning_rate': 0.04283014165290161, 'max_iter': 869, 'max_depth': 12, 'min_samples_leaf': 23, 'l2_regularization': 8.435744500380467, 'max_bins': 222, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:42:49,701] Trial 139 finished with value: 0.9645249489624577 and parameters: {'learning_rate': 0.06785718940459576, 'max_iter': 869, 'max_depth': 10, 'min_samples_leaf': 23, 'l2_regularization': 8.544265409193663, 'max_bins': 223, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:43:05,093] Trial 140 finished with value: 0.9648618025303431 and parameters: {'learning_rate': 0.04384541106647757, 'max_iter': 950, 'max_depth': 11, 'min_samples_leaf': 17, 'l2_regularization': 9.601911149970066, 'max_bins': 246, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:43:20,170] Trial 141 finished with value: 0.964842553252191 and parameters: {'learning_rate': 0.033017592756867345, 'max_iter': 892, 'max_depth': 12, 'min_samples_leaf': 24, 'l2_regularization': 7.758171057400685, 'max_bins': 210, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:43:34,950] Trial 142 finished with value: 0.964794435151418 and parameters: {'learning_rate': 0.03479745383378098, 'max_iter': 860, 'max_depth': 12, 'min_samples_leaf': 21, 'l2_regularization': 8.448584320407086, 'max_bins': 227, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:43:50,221] Trial 143 finished with value: 0.9647655598447514 and parameters: {'learning_rate': 0.05466571802176025, 'max_iter': 968, 'max_depth': 13, 'min_samples_leaf': 22, 'l2_regularization': 7.456148618538757, 'max_bins': 220, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:44:06,010] Trial 144 finished with value: 0.9652082770321357 and parameters: {'learning_rate': 0.02772608659443197, 'max_iter': 916, 'max_depth': 13, 'min_samples_leaf': 25, 'l2_regularization': 6.970140561492914, 'max_bins': 212, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:44:21,667] Trial 145 finished with value: 0.9647463110297455 and parameters: {'learning_rate': 0.028318679490002267, 'max_iter': 922, 'max_depth': 11, 'min_samples_leaf': 23, 'l2_regularization': 6.8502458044705365, 'max_bins': 235, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:44:38,322] Trial 146 finished with value: 0.9647366859275234 and parameters: {'learning_rate': 0.021392206995199926, 'max_iter': 937, 'max_depth': 12, 'min_samples_leaf': 15, 'l2_regularization': 7.155150823169086, 'max_bins': 216, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:44:51,289] Trial 147 finished with value: 0.9651505291976795 and parameters: {'learning_rate': 0.04380717275725785, 'max_iter': 769, 'max_depth': 13, 'min_samples_leaf': 20, 'l2_regularization': 6.4904516085081045, 'max_bins': 223, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# ...
# [I 2024-12-13 19:45:52,720] Trial 152 finished with value: 0.9651986505404752 and parameters: {'learning_rate': 0.043714910464658266, 'max_iter': 813, 'max_depth': 12, 'min_samples_leaf': 21, 'l2_regularization': 6.93079333477188, 'max_bins': 216, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:46:06,527] Trial 153 finished with value: 0.9649772907889179 and parameters: {'learning_rate': 0.025593836396681804, 'max_iter': 803, 'max_depth': 13, 'min_samples_leaf': 20, 'l2_regularization': 6.885936694676847, 'max_bins': 215, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:46:19,809] Trial 154 finished with value: 0.9649291717618527 and parameters: {'learning_rate': 0.04716348895636143, 'max_iter': 831, 'max_depth': 11, 'min_samples_leaf': 18, 'l2_regularization': 6.485928197869208, 'max_bins': 205, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:46:32,266] Trial 155 finished with value: 0.9649291666672456 and parameters: {'learning_rate': 0.05407890354585027, 'max_iter': 771, 'max_depth': 14, 'min_samples_leaf': 21, 'l2_regularization': 7.000127388017972, 'max_bins': 229, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:46:44,397] Trial 156 finished with value: 0.9648425546416293 and parameters: {'learning_rate': 0.03895061415217965, 'max_iter': 717, 'max_depth': 12, 'min_samples_leaf': 16, 'l2_regularization': 6.745445519677033, 'max_bins': 217, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:46:56,314] Trial 157 finished with value: 0.964717435259933 and parameters: {'learning_rate': 0.08803595441001448, 'max_iter': 805, 'max_depth': 12, 'min_samples_leaf': 20, 'l2_regularization': 6.341446867656172, 'max_bins': 208, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:47:10,038] Trial 158 finished with value: 0.9650927859946842 and parameters: {'learning_rate': 0.031225084926516267, 'max_iter': 827, 'max_depth': 14, 'min_samples_leaf': 24, 'l2_regularization': 7.3207235723929305, 'max_bins': 211, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:47:22,792] Trial 159 finished with value: 0.9649484215031509 and parameters: {'learning_rate': 0.028970423883069574, 'max_iter': 763, 'max_depth': 13, 'min_samples_leaf': 22, 'l2_regularization': 5.9763109947102215, 'max_bins': 118, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:47:36,817] Trial 160 finished with value: 0.9652564006906619 and parameters: {'learning_rate': 0.03656240943783593, 'max_iter': 851, 'max_depth': 12, 'min_samples_leaf': 19, 'l2_regularization': 7.050129153077855, 'max_bins': 239, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:47:52,865] Trial 161 finished with value: 0.9596262063624325 and parameters: {'learning_rate': 0.8787692030121764, 'max_iter': 955, 'max_depth': 12, 'min_samples_leaf': 17, 'l2_regularization': 6.702543917906924, 'max_bins': 237, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:48:07,034] Trial 162 finished with value: 0.9650735339376556 and parameters: {'learning_rate': 0.03654944926205866, 'max_iter': 857, 'max_depth': 13, 'min_samples_leaf': 19, 'l2_regularization': 7.1447316599559585, 'max_bins': 240, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:48:20,421] Trial 163 finished with value: 0.9649099257257234 and parameters: {'learning_rate': 0.044502752973972735, 'max_iter': 831, 'max_depth': 11, 'min_samples_leaf': 21, 'l2_regularization': 6.941284533391151, 'max_bins': 227, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:48:34,669] Trial 164 finished with value: 0.9650735399585549 and parameters: {'learning_rate': 0.03259918526105422, 'max_iter': 883, 'max_depth': 12, 'min_samples_leaf': 22, 'l2_regularization': 6.163843573264682, 'max_bins': 232, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:48:49,374] Trial 165 finished with value: 0.9649676675392802 and parameters: {'learning_rate': 0.024184909109032305, 'max_iter': 847, 'max_depth': 13, 'min_samples_leaf': 15, 'l2_regularization': 6.413966210987447, 'max_bins': 224, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:49:04,440] Trial 166 finished with value: 0.9648810536610796 and parameters: {'learning_rate': 0.040312465702721706, 'max_iter': 910, 'max_depth': 12, 'min_samples_leaf': 19, 'l2_regularization': 6.626375724213798, 'max_bins': 219, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:49:19,691] Trial 167 finished with value: 0.964794430519957 and parameters: {'learning_rate': 0.057741753594714736, 'max_iter': 969, 'max_depth': 14, 'min_samples_leaf': 18, 'l2_regularization': 7.373095952123569, 'max_bins': 212, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:49:33,456] Trial 168 finished with value: 0.9648617997514666 and parameters: {'learning_rate': 0.026859590299140545, 'max_iter': 819, 'max_depth': 13, 'min_samples_leaf': 27, 'l2_regularization': 5.563091006010759, 'max_bins': 227, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:49:45,463] Trial 169 finished with value: 0.9649869214488932 and parameters: {'learning_rate': 0.048549116796009956, 'max_iter': 693, 'max_depth': 12, 'min_samples_leaf': 2, 'l2_regularization': 7.09517705293667, 'max_bins': 220, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:49:52,928] Trial 170 finished with value: 0.9303780592131361 and parameters: {'learning_rate': 0.034638924794074426, 'max_iter': 940, 'max_depth': 1, 'min_samples_leaf': 21, 'l2_regularization': 6.84176764453441, 'max_bins': 232, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:50:07,081] Trial 171 finished with value: 0.9648425546416293 and parameters: {'learning_rate': 0.030014715703957924, 'max_iter': 817, 'max_depth': 14, 'min_samples_leaf': 24, 'l2_regularization': 9.992756286519802, 'max_bins': 209, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:50:20,687] Trial 172 finished with value: 0.9648714239273964 and parameters: {'learning_rate': 0.030963258738849378, 'max_iter': 788, 'max_depth': 14, 'min_samples_leaf': 24, 'l2_regularization': 7.391406755920704, 'max_bins': 214, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:50:34,591] Trial 173 finished with value: 0.9650735344008016 and parameters: {'learning_rate': 0.041364308563842093, 'max_iter': 879, 'max_depth': 13, 'min_samples_leaf': 26, 'l2_regularization': 7.286991566866673, 'max_bins': 204, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:50:47,539] Trial 174 finished with value: 0.9651120292519371 and parameters: {'learning_rate': 0.03692494792731749, 'max_iter': 737, 'max_depth': 14, 'min_samples_leaf': 23, 'l2_regularization': 6.982775518906471, 'max_bins': 212, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:51:00,069] Trial 175 finished with value: 0.9649484219662968 and parameters: {'learning_rate': 0.038026632599366936, 'max_iter': 719, 'max_depth': 13, 'min_samples_leaf': 22, 'l2_regularization': 6.545619473012303, 'max_bins': 223, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:51:15,638] Trial 176 finished with value: 0.9651890277539836 and parameters: {'learning_rate': 0.04633212171622479, 'max_iter': 748, 'max_depth': 12, 'min_samples_leaf': 17, 'l2_regularization': 6.9443304174034335, 'max_bins': 217, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:51:30,772] Trial 177 finished with value: 0.9647366854643774 and parameters: {'learning_rate': 0.04744774995629922, 'max_iter': 916, 'max_depth': 11, 'min_samples_leaf': 17, 'l2_regularization': 6.282693220120529, 'max_bins': 217, 'early_stopping': True}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:51:49,024] Trial 178 finished with value: 0.9652275239945574 and parameters: {'learning_rate': 0.043105088597675534, 'max_iter': 737, 'max_depth': 12, 'min_samples_leaf': 14, 'l2_regularization': 5.834675397122153, 'max_bins': 38, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:52:11,806] Trial 179 finished with value: 0.9642939756873308 and parameters: {'learning_rate': 0.06992235222660287, 'max_iter': 971, 'max_depth': 11, 'min_samples_leaf': 14, 'l2_regularization': 5.341317194382395, 'max_bins': 243, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:52:31,166] Trial 180 finished with value: 0.9647463119560378 and parameters: {'learning_rate': 0.0538781013006053, 'max_iter': 788, 'max_depth': 12, 'min_samples_leaf': 16, 'l2_regularization': 5.814464054251978, 'max_bins': 228, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:52:49,575] Trial 181 finished with value: 0.9652275244577033 and parameters: {'learning_rate': 0.04179182383891153, 'max_iter': 738, 'max_depth': 13, 'min_samples_leaf': 20, 'l2_regularization': 5.986351403967129, 'max_bins': 128, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:53:07,239] Trial 182 finished with value: 0.9651409082637723 and parameters: {'learning_rate': 0.04284852326665659, 'max_iter': 707, 'max_depth': 13, 'min_samples_leaf': 20, 'l2_regularization': 6.021683849123568, 'max_bins': 40, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:53:25,324] Trial 183 finished with value: 0.9651216571330357 and parameters: {'learning_rate': 0.04227424808404929, 'max_iter': 739, 'max_depth': 12, 'min_samples_leaf': 20, 'l2_regularization': 5.90564993037816, 'max_bins': 80, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:53:42,183] Trial 184 finished with value: 0.9650831613556082 and parameters: {'learning_rate': 0.05820434918901469, 'max_iter': 702, 'max_depth': 13, 'min_samples_leaf': 18, 'l2_regularization': 6.140310193628701, 'max_bins': 32, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:53:58,686] Trial 185 finished with value: 0.9651024087811759 and parameters: {'learning_rate': 0.049991803277096805, 'max_iter': 675, 'max_depth': 12, 'min_samples_leaf': 19, 'l2_regularization': 5.629632053486578, 'max_bins': 48, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:54:14,933] Trial 186 finished with value: 0.9650061679481687 and parameters: {'learning_rate': 0.0453324262521788, 'max_iter': 649, 'max_depth': 13, 'min_samples_leaf': 17, 'l2_regularization': 5.997712840279029, 'max_bins': 40, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:54:34,197] Trial 187 finished with value: 0.9651505305871177 and parameters: {'learning_rate': 0.03640484346580187, 'max_iter': 759, 'max_depth': 11, 'min_samples_leaf': 13, 'l2_regularization': 6.330281625765534, 'max_bins': 37, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:54:53,392] Trial 188 finished with value: 0.9651697821810004 and parameters: {'learning_rate': 0.036016223824339305, 'max_iter': 763, 'max_depth': 12, 'min_samples_leaf': 12, 'l2_regularization': 5.7833245112032445, 'max_bins': 40, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:55:12,398] Trial 189 finished with value: 0.964919548512215 and parameters: {'learning_rate': 0.03535764412513707, 'max_iter': 758, 'max_depth': 12, 'min_samples_leaf': 13, 'l2_regularization': 5.156306715115834, 'max_bins': 57, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:55:31,825] Trial 190 finished with value: 0.9651601529104633 and parameters: {'learning_rate': 0.03427967901159433, 'max_iter': 767, 'max_depth': 11, 'min_samples_leaf': 11, 'l2_regularization': 5.788274244320516, 'max_bins': 48, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:55:51,006] Trial 191 finished with value: 0.9650157930503909 and parameters: {'learning_rate': 0.033670397594870984, 'max_iter': 761, 'max_depth': 11, 'min_samples_leaf': 11, 'l2_regularization': 5.5070554493830475, 'max_bins': 38, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:56:09,856] Trial 192 finished with value: 0.9649291726881449 and parameters: {'learning_rate': 0.037245032132892736, 'max_iter': 730, 'max_depth': 11, 'min_samples_leaf': 14, 'l2_regularization': 5.74328896122289, 'max_bins': 69, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:56:29,968] Trial 193 finished with value: 0.9650542855857956 and parameters: {'learning_rate': 0.028792297750301017, 'max_iter': 783, 'max_depth': 10, 'min_samples_leaf': 15, 'l2_regularization': 6.235966859805133, 'max_bins': 47, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:56:48,246] Trial 194 finished with value: 0.9646308218448786 and parameters: {'learning_rate': 0.046961588214270024, 'max_iter': 747, 'max_depth': 12, 'min_samples_leaf': 12, 'l2_regularization': 5.815115748654399, 'max_bins': 91, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:57:07,613] Trial 195 finished with value: 0.9650254190789053 and parameters: {'learning_rate': 0.039589256295783526, 'max_iter': 770, 'max_depth': 12, 'min_samples_leaf': 13, 'l2_regularization': 6.390654683608228, 'max_bins': 45, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:57:27,966] Trial 196 finished with value: 0.9652756527476907 and parameters: {'learning_rate': 0.03257435968022282, 'max_iter': 810, 'max_depth': 12, 'min_samples_leaf': 10, 'l2_regularization': 5.353080334719641, 'max_bins': 36, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:57:48,807] Trial 197 finished with value: 0.9650254107422753 and parameters: {'learning_rate': 0.03156927559754385, 'max_iter': 818, 'max_depth': 11, 'min_samples_leaf': 10, 'l2_regularization': 5.475102415766017, 'max_bins': 38, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:58:09,555] Trial 198 finished with value: 0.9648233049003313 and parameters: {'learning_rate': 0.023786570661964376, 'max_iter': 791, 'max_depth': 12, 'min_samples_leaf': 11, 'l2_regularization': 4.85849315925321, 'max_bins': 36, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# [I 2024-12-13 19:58:30,661] Trial 199 finished with value: 0.9649676675392802 and parameters: {'learning_rate': 0.027271311467317174, 'max_iter': 802, 'max_depth': 12, 'min_samples_leaf': 12, 'l2_regularization': 5.263299349333839, 'max_bins': 54, 'early_stopping': False}. Best is trial 129 with value: 0.9653045224966039.
# Best hyperparameters: {'learning_rate': 0.03400676560252863, 'max_iter': 925, 'max_depth': 13, 'min_samples_leaf': 16, 'l2_regularization': 8.763352346928274, 'max_bins': 209, 'early_stopping': False}
# Best accuracy: 0.9653045224966039
# Test Accuracy: 0.9643132121958731

# %%
# Tracer la courbe d'apprentissage
plot_learning_curve(
        best_model, 
        "Learning Curve: Optimized Hist Gradient Boosting",
        X, 
        y, 
        train_sizes=[500, 1000, 2000, 3000, 4000, 5000, 10000, 20000, 30000], 
        ylim=(0.1, 1.01)
    )
